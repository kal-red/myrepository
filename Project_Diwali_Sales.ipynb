# %%
# importing pandas to read the dataset file

# %%
import pandas as pd

# %%
ds=pd.read_excel('Diwali Sales Data.xlsx')

# %%
ds
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
ds.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
ds.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
# dropping null columns

# %%
ds.drop(columns=['Status','unnamed1'], inplace=True)

# %%
ds.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# dropping null rows

# %%
ds_cleaned=ds.dropna()

# %%
ds_cleaned
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
ds.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
ds_cleaned.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610858
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
ds_cleaned.shape
# Out:
# (11239, 13)

# %%
# count the number of distinct products (IDs) being sold

# %%
#select count(*)
#from ds
#group by Product_ID
#order by asc

# %%
ds_cleaned.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# identifying the top 20 most sold products (IDs)

# %%
ds_cleaned.groupby('Product_ID')['Product_ID'].count().sort_values(ascending=False).head()
# Out:
# Product_ID
# P00265242    53
# P00110942    44
# P00184942    37
# P00237542    35
# P00112142    34
# Name: Product_ID, dtype: int64

# %%
product_counts=ds_cleaned.value_counts('Product_ID').sort_values(ascending=False).head()

# %%
product_counts
# Out:
# Product_ID
# P00265242    53
# P00110942    44
# P00184942    37
# P00237542    35
# P00112142    34
# Name: count, dtype: int64

# %%
# identifying the number of males and females

# %%
gender_counts=ds_cleaned.value_counts('Gender')

# %%
gender_counts
# Out:
# Gender
# F    7832
# M    3407
# Name: count, dtype: int64

# %%
# identifying number of buyers based on age groups

# %%
age_group_counts=ds_cleaned.value_counts('Age Group')

# %%
age_group_counts
# Out:
# Age Group
# 26-35    4541
# 36-45    2283
# 18-25    1879
# 46-50     983
# 51-55     830
# 55+       427
# 0-17      296
# Name: count, dtype: int64

# %%
# Marital Status

# %%
marital_status_counts=ds_cleaned.value_counts('Marital_Status')

# %%
marital_status_counts
# Out:
# Marital_Status
# 0    6518
# 1    4721
# Name: count, dtype: int64

# %%
# Sales by State

# %%
state_counts=ds_cleaned.value_counts('State')

# %%
state_counts
# Out:
# State
# Uttar Pradesh       1944
# Maharashtra         1525
# Karnataka           1304
# Delhi               1104
# Madhya Pradesh       921
# Andhra Pradesh       811
# Himachal Pradesh     608
# Kerala               453
# Haryana              452
# Bihar                434
# Gujarat              427
# Jharkhand            380
# Uttarakhand          320
# Rajasthan            231
# Punjab               200
# Telangana            125
# Name: count, dtype: int64

# %%
# Sales by Zone

# %%
zone_counts=ds_cleaned.value_counts('Zone')

# %%
zone_counts
# Out:
# Zone
# Central     4289
# Southern    2693
# Western     1952
# Northern    1491
# Eastern      814
# Name: count, dtype: int64

# %%
# Sales by Occupation

# %%
occupation_counts=ds_cleaned.value_counts('Occupation')

# %%
occupation_counts
# Out:
# Occupation
# IT Sector          1583
# Healthcare         1408
# Aviation           1310
# Banking            1137
# Govt                854
# Hospitality         703
# Media               637
# Automobile          565
# Chemical            541
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             349
# Agriculture         283
# Name: count, dtype: int64

# %%
# Sales by Product Category

# %%
category_counts=ds_cleaned.value_counts('Product_Category')

# %%
category_counts
# Out:
# Product_Category
# Clothing & Apparel       2655
# Food                     2490
# Electronics & Gadgets    2087
# Footwear & Shoes         1059
# Household items           520
# Beauty                    422
# Games & Toys              386
# Sports Products           356
# Furniture                 352
# Pet Care                  212
# Office                    113
# Stationery                112
# Books                     103
# Auto                       97
# Decor                      96
# Veterinary                 81
# Tupperware                 72
# Hand & Power Tools         26
# Name: count, dtype: int64

# %%
# Sales by number of orders

# %%
orders_counts=ds_cleaned.value_counts('Orders')

# %%
orders_counts
# Out:
# Orders
# 2    2893
# 1    2808
# 4    2773
# 3    2765
# Name: count, dtype: int64

# %%
# Average amount per sale

# %%
ds_cleaned['Amount'].mean()
# Out:
# 9453.610857727557

# %%
# importing matplotlib.pyplot and seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
ds_cleaned.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
# plotting the top 5 most sold products (IDs)

# %%
plt.bar(product_counts.index,product_counts.values)
plt.title('Top 5 Product Sales')
plt.xlabel('Product ID')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Gender Counts/Distribution

# %%
plt.pie(gender_counts,labels=gender_counts.index, autopct='%0.1f%%')
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# Age Group Counts/Distribution

# %%
plt.pie(age_group_counts,labels=age_group_counts.index, autopct='%0.1f%%')
plt.title('Age Group Distribution')
# Out:
# Text(0.5, 1.0, 'Age Group Distribution')

# %%
# Marital Status Distribution/Counts

# %%
plt.pie(marital_status_counts,labels=marital_status_counts.index, autopct='%0.1f%%')
plt.title('Marital Status Distribution')
# Out:
# Text(0.5, 1.0, 'Marital Status Distribution')

# %%
# Count by State

# %%
plt.bar(state_counts.index,state_counts.values)
plt.title('Count by State')
plt.xlabel('States')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Count by State

# %%
plt.bar(zone_counts.index,zone_counts.values)
plt.title('Count by Zones')
plt.xlabel('Zone')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.pie(zone_counts,labels=zone_counts.index,autopct='%0.1f%%')
plt.title('Count by Zone')
# Out:
# Text(0.5, 1.0, 'Count by Zone')

# %%
# Count by Occupation

# %%
plt.bar(occupation_counts.index,occupation_counts.values)
plt.title('Count by Occupation')
# Out:
# Text(0.5, 1.0, 'Count by Occupation')

# %%
# Count by Category

# %%
plt.bar(category_counts.index,category_counts.values)
plt.title('Count by Category')
# Out:
# Text(0.5, 1.0, 'Count by Category')

# %%
# Distribution of Count by Age Group

# %%
sns.displot(data=ds_cleaned,x='Age Group')
plt.title('Distribution of Age Group')
# Out:
# Text(0.5, 1.0, 'Distribution of Age Group')

# %%
# Boxplot by Gender

# %%
sns.boxplot(data=ds_cleaned,x='Gender',y='Amount')
plt.title('Amount by Gender')
# Out:
# Text(0.5, 1.0, 'Amount by Gender')

# %%
sns.violinplot(data=ds_cleaned,x='Age Group',y='Amount')
plt.title('Amount by Age Group')
# Out:
# Text(0.5, 1.0, 'Amount by Age Group')

# %%
sns.boxplot(data=ds_cleaned,x='Marital_Status',y='Amount',hue='Gender')
plt.title('Amount by Marital Status')
# Out:
# Text(0.5, 1.0, 'Amount by Marital Status')

# %%
sns.pairplot(ds_cleaned)

# %%
ds_cleaned.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0
