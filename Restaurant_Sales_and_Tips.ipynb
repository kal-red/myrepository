# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# # Import Seaborn

# %%
import seaborn as sns

# %% [markdown]
# # Import Dataset

# %%
dr1=sns.load_dataset('tips')

# %%
dr1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
dr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
dr1.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
dr1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dr1.value_counts('sex')
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %% [markdown]
# # Plotting Countplot

# %%
sns.countplot(data=dr1,x='sex',hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # Plotting Jointplot

# %%
sns.jointplot(data=dr1,x='total_bill',y='tip',hue='sex')

# %% [markdown]
# # Plotting Distribution of Data

# %%
sns.displot(data=dr1,x='total_bill')
plt.title('Distribution of Total_Bill')
plt.ylabel('Total Count')
# Out:
# Text(13.819444444444445, 0.5, 'Total Count')

# %%
sns.displot(data=dr1,x='tip')
plt.title('Distribution of Tips')
plt.ylabel('Total Count')
# Out:
# Text(13.819444444444445, 0.5, 'Total Count')

# %%
# Plot Gender v/s Tip

# %%
# Average Tip by Gender

# %%
sns.barplot(data=dr1,x='sex',y='tip')
plt.title('Gender v/s Tips')
# Out:
# Text(0.5, 1.0, 'Gender v/s Tips')

# %%
dr1.groupby('sex')['tip'].mean()
# Out:
# C:\Users\kalya\AppData\Local\Temp\ipykernel_6280\3765240081.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dr1.groupby('sex')['tip'].mean()
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
# Total Tip by Gender

# %%
sns.barplot(data=dr1,x='sex',y='tip',estimator=np.sum)
plt.title('Total Tips by Gender')
# Out:
# Text(0.5, 1.0, 'Total Tips by Gender')

# %%
dr1.groupby('sex')['tip'].sum()
# Out:
# C:\Users\kalya\AppData\Local\Temp\ipykernel_6280\1399710069.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dr1.groupby('sex')['tip'].sum()
# sex
# Male      485.07
# Female    246.51
# Name: tip, dtype: float64

# %%
dr1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
v2=dr1.value_counts('smoker')

# %%
v2
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
v2.values
# Out:
# array([151,  93], dtype=int64)

# %%
v2.index
# Out:
# CategoricalIndex(['No', 'Yes'], categories=['Yes', 'No'], ordered=False, dtype='category', name='smoker')

# %%
plt.pie(v2.values,labels=v2.index,autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1ea1a474350>,
# ...
#  [Text(-0.4012471747910624, 1.0242073543585746, 'No'),
#   Text(0.4012470788978477, -1.024207391926042, 'Yes')],
#  [Text(-0.2188620953405795, 0.5586585569228588, '61.89%'),
#   Text(0.21886204303518964, -0.5586585774142045, '38.11%')])

# %%
# Tips by smokers & non-smokers

# %%
sns.barplot(data=dr1,x='smoker',y='tip')
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(data=dr1,x='smoker',y='tip',estimator=np.sum)
# Out:
# <Axes: xlabel='smoker', ylabel='tip'>

# %%
dr1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Average total bill by day

# %%
dr1.groupby('day')['total_bill'].mean()
# Out:
# C:\Users\kalya\AppData\Local\Temp\ipykernel_6280\3957703434.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   dr1.groupby('day')['total_bill'].mean()
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
sns.barplot(data=dr1,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Average tips by day

# %%
sns.barplot(data=dr1,x='day',y='tip',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Boxplot

# %%
sns.boxplot(data=dr1,x='day',y='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=dr1,x='day',y='tip',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.boxplot(data=dr1,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
dr1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dr1.value_counts('time')
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.countplot(data=dr1,x='time',hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.boxplot(data=dr1,x='time',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %%
sns.boxplot(data=dr1,x='size',y='total_bill')
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.boxplot(data=dr1,x='size',y='tip')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %% [markdown]
# # Violin Chart

# %%
sns.violinplot(data=dr1,x='day',y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=dr1,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(data=dr1,x='day',y='tip',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# # Swarm Plot

# %%
sns.swarmplot(data=dr1,x='day',y='tip')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.swarmplot(data=dr1,x='day',y='total_bill',hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(dr1)

# %%
dr1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dr2=dr1.drop(columns=['sex','smoker','day','time'])

# %%
dr2
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(dr2.corr(),annot=True)
# Out:
# <Axes: >
